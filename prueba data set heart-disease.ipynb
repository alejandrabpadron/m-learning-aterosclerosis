# %%
import pandas as pd
import numpy as np

# %%
mainpath='/Users/ALITO/Documents'

# %%
data=pd.read_csv(mainpath+'/'+'Set/NumMuertes.csv')

# %%
data.head()
# Out:
#   CODIGO DE MUNICIPIO  MUNICIPIO DEPARTAMENTO  MORTALIDAD POR OBESIDAD  \
# 0                5001  Antioquia     Medellín                     11.0
# 1                5002  Antioquia    Abejorral                      NaN
# 2                5004  Antioquia     Abriaquí                      NaN
# 3                5021  Antioquia   Alejandría                      NaN
# 4                5030  Antioquia        Amagá                      NaN
#
#    MORTALIDAD POR CANCER  MORTALIDAD POR CARDIOVASCULAR  \
# 0                 3242.0                         2196.0
# 1                   24.0                           23.0
# 2                    2.0                            2.0
# 3                    3.0                            4.0
# 4                   31.0                           27.0
#
#    MORTALIDAD POR HIPERTENSION  MORTALIDAD POR DIABETES  \
# 0                        682.0                    283.0
# 1                          3.0                      4.0
# ...

# %%
data.corr()
# Out:
#                                                     MORTALIDAD POR OBESIDAD  \
# MORTALIDAD POR OBESIDAD                                            1.000000
# MORTALIDAD POR CANCER                                              0.996505
# MORTALIDAD POR CARDIOVASCULAR                                      0.997272
# MORTALIDAD POR HIPERTENSION                                        0.996014
# MORTALIDAD POR DIABETES                                            0.997461
# MORTALIDAD POR ENFERMEDADES RESPIRATORIAS                          0.997229
# MORTALIDAD POR CONSUMO DE ALCOHOL                                  0.992550
# MORTALIDAD POR CONSUMO DE DROGAS ILICITAS                          0.990688
# MORTALIDAD POR ACCIDENTES DE TRANSPORTE                            0.996351
# HOMICIDIOS                                                         0.997572
# MORTALIDAD POR ENVENENAMIENTO ACCIDENTAL POR, Y...                 0.989900
# ...
