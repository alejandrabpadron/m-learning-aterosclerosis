# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mainpath='/Users/ALITO/Documents'

# %%
data=pd.read_csv(mainpath+'/'+'Set/NumMuertes.csv',
                 names=['id','municipio','dpto','obesidad','cancer','cardiovascular','hipertension','diabetes',
                        'enf_respiratorias','alcohol','drogas','accidentes','homicidios','envenenamiento'])

# %%
data.head()
# Out:
#      id  municipio        dpto  obesidad  cancer  cardiovascular  \
# 0  5001  Antioquia    Medellín      11.0  3242.0          2196.0
# 1  5002  Antioquia   Abejorral       NaN    24.0            23.0
# 2  5004  Antioquia    Abriaquí       NaN     2.0             2.0
# 3  5021  Antioquia  Alejandría       NaN     3.0             4.0
# 4  5030  Antioquia       Amagá       NaN    31.0            27.0
#
#    hipertension  diabetes  enf_respiratorias  alcohol  drogas  accidentes  \
# 0         682.0     283.0             1811.0     41.0     1.0       343.0
# 1           3.0       4.0               12.0      NaN     NaN         2.0
# 2           1.0       NaN                1.0      NaN     NaN         NaN
# 3           4.0       NaN                4.0      NaN     NaN         NaN
# 4           3.0       4.0               25.0      NaN     NaN         6.0
#
#    homicidios  envenenamiento
# 0       460.0            15.0
# 1         4.0             NaN
# 2         NaN             NaN
# ...

# %%
data.corr()
# Out:
#                          id  obesidad    cancer  cardiovascular  hipertension  \
# id                 1.000000 -0.059603 -0.022216       -0.010639     -0.035143
# obesidad          -0.059603  1.000000  0.910811        0.921884      0.878661
# cancer            -0.022216  0.910811  1.000000        0.990866      0.981942
# cardiovascular    -0.010639  0.921884  0.990866        1.000000      0.969167
# hipertension      -0.035143  0.878661  0.981942        0.969167      1.000000
# diabetes           0.004167  0.936250  0.959140        0.977319      0.933451
# enf_respiratorias -0.020694  0.918346  0.993004        0.989950      0.982303
# alcohol           -0.039787  0.967821  0.941462        0.945324      0.888750
# drogas            -0.286009  0.732381  0.857317        0.882967      0.838365
# accidentes         0.008837  0.916376  0.958410        0.964641      0.936375
# homicidios         0.015116  0.927409  0.873941        0.894661      0.829541
# ...

# %%
sns.heatmap(data.corr(), square=True, annot=True)

# %%
sns.boxplot(x="obesidad", y="cardiovascular", data=data)

# %%
sns.lmplot("obesidad", "obesidad", hue="diabetes", data=data)
